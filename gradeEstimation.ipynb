# %%
import pandas as pd

# %%
df = pd.read_csv('student-mat.csv', sep=';')
df = df[['G1', 'G2', 'G3', 'studytime', 'failures', 'absences', 'age']]
df.head()
# Out:
#    G1  G2  G3  studytime  failures  absences  age
# 0   5   6   6          2         0         6   18
# 1   5   5   6          2         0         4   17
# 2   7   8  10          2         3        10   15
# 3  15  14  15          3         0         2   15
# 4   6  10  10          2         0         4   16

# %%
df.rename(columns={'G1': 'grade1', 'G2': 'grade2', 'G3': 'final_grade'}, inplace=True)

# %%
df.dtypes
# Out:
# grade1         int64
# grade2         int64
# final_grade    int64
# studytime      int64
# failures       int64
# absences       int64
# age            int64
# dtype: object

# %%
import numpy as np
y=np.array(df['final_grade'])
X=np.array(df.drop('final_grade', axis=1))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linear.score(X_test, y_test)
# Out:
# 0.8325898318712226

# %%
linear.score(X_train, y_train)
# Out:
# 0.8261275475197141

# %%
print('Coefficients: \n', linear.coef_)
print('Intercept: \n', linear.intercept_)
# Out:
# Coefficients:
#  [ 0.19575962  0.95558174 -0.24215827  0.12730705  0.03566925 -0.23224281]
# Intercept:
#  2.1549097406751443

# %%
predictions = linear.predict(X_test)
print(predictions)
# Out:
# [12.49256846 16.80417249 16.44750855 13.74176323 12.05453068  8.72564344
#   5.67245823  7.44916523  7.73480803 12.26190072 12.99348446 10.1351467
#   7.71789122  8.4229743  10.28936702 12.79772483  8.40474697 12.69661566
#  12.20872249  7.94053593 13.94743831  6.77229201  9.57594355 11.35271762
#  14.34899291 16.44750855 14.10997052  6.59177855  7.79921224 15.3484644
#   8.40637485 12.79229887  8.57396317 13.02833976  3.88894734 10.27070276
#  -1.33521964  9.5510037  10.76214022 10.25206989 19.67213718  8.64853312
#   6.75562548  8.83437728  9.09890684  7.46077564  6.19163007  6.34108663
#  15.14599226  4.06676847  6.43250211  8.82283394 10.77873967 12.17898033
#   4.40394704  8.42460219 10.72728491  3.29135465  8.03145506 10.4601868
#  19.20636502  9.44155414 11.65977997 14.86816475  5.32304559 10.65431854
#   9.21927961  6.4837351  16.55212728  8.40970485  8.31678051 17.79628019
#  12.53055964 11.93173743 17.09950899 11.88854174  4.7018521  15.49192681
#  10.82193537]

# %%
from sklearn.metrics import mean_squared_error

print('Mean Squared Error: ', mean_squared_error(y_test, predictions))
# Out:
# Mean Squared Error:  3.1978265956263536
